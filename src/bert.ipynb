# %%
import torch.nn as nn
import torch
import pandas as pd
import copy
import random
import numpy as np

# %%
max_len = 50
embed_dim = 256

# %%
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.backends.mps.is_available():
        torch.mps.manual_seed(seed)
set_seed()

# %%
df = pd.read_csv('/Users/baonguyen/IU/thesis/data/clean_data/data_with_bertopic_column.csv')

# %%
df['review_date']=pd.to_datetime(df['review_date'])
df_sorted = df.sort_values('review_date')

# %%
unique_item_id = set(df_sorted['item_id'])
item_to_index = {item:idx +1 for idx , item in enumerate(unique_item_id)}
index_to_item = {idx+1:item for idx , item in enumerate(unique_item_id)}

# %%
# Step 1: Group and aggregate
user_item_sequence = (
    df_sorted.groupby('user_id')[['item_id']]
    .agg(list)
    .to_dict(orient='index')
)

# Step 2: Remove users with fewer than 2 item_ids
user_item_sequence = {
    user: val
    for user, val in user_item_sequence.items()
    if len(val['item_id']) >= 2
}

# %%
user_item_to_index_sequence = {}
for user,value in user_item_sequence.items():
    user_item_to_index_sequence[user] = {'item_id':[item_to_index[item] for item in value['item_id']]}

# %%
def mask_sequence(sequence: dict, mask_ratio: float):
    labels = {}
    mask_seq = {}
    for user, seq in sequence.items():
        mask_seq[user] = copy.deepcopy(seq)  # Deep copy so original is untouched
        labels[user] = [-100] * len(seq['item_id'])
        for i in range(len(mask_seq[user]['item_id'])):
            if random.random() < mask_ratio:
                labels[user][i] = mask_seq[user]['item_id'][i]  # Save original item id
                mask_seq[user]['item_id'][i] = 0       # Mask the item id
               
    return mask_seq, labels

# %%
def padding(mask_seq, labels, max_len=64, pad_item=0, pad_topic=0, pad_label=-100):
    """
    Pads all user sequences in mask_seq and labels to max_len.
    
    Args:
        mask_seq: dict of user_id -> {'item_id': [...], 'Topic': [...]}
        labels: dict of user_id -> [...]
        max_len: desired length after padding
        pad_item: value for padding 'item_id'
        pad_topic: value for padding 'Topic'
        pad_label: value for padding labels

    Returns:
        padded_mask_seq, padded_labels (dicts)
    """
    def pad(seq, max_len, pad_value):
        if len(seq) < max_len:
            return seq + [pad_value] * (max_len - len(seq))
        else:
            return seq[len(seq)-max_len:len(seq)]
    
    padded_mask_seq = {}
    padded_labels = {}

    for user in mask_seq:
        padded_mask_seq[user] = {
            'item_id': pad(mask_seq[user]['item_id'], max_len, pad_item)
        }
        padded_labels[user] = pad(labels[user], max_len, pad_label)
    
    return padded_mask_seq, padded_labels

# %% [markdown]
# # bert architect

# %%
class BertEmbeddings(nn.Module):
    def __init__(self,vocab_size, hidden_size, max_len, dropout):
        super().__init__()
        self.max_len = max_len
        self.word_embeddings = nn.Embedding(vocab_size,hidden_size)
        self.position_encoding = nn.Embedding(max_len,hidden_size)
        self.LayerNorm = nn.LayerNorm(hidden_size)
        self.Dropout = nn.Dropout(dropout)

    def forward(self,input_ids):
        position_ids = torch.arange(self.max_len, dtype=torch.long, device=input_ids.device).unsqueeze(0)
        word_emb = self.word_embeddings(input_ids)
        pos_emb = self.position_encoding(position_ids)
        embeddings = word_emb + pos_emb
        embeddings = self.LayerNorm(embeddings)
        return self.Dropout(embeddings)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import math

class BertSdpaSelfAttention(nn.Module):
    def __init__(self, hidden_size=512, num_heads=8, dropout=0.1):
        super().__init__()
        self.num_heads = num_heads
        self.head_dim = hidden_size // num_heads

        self.q_proj = nn.Linear(hidden_size, hidden_size)
        self.k_proj = nn.Linear(hidden_size, hidden_size)
        self.v_proj = nn.Linear(hidden_size, hidden_size)
        self.attn_dropout = nn.Dropout(dropout)

    def forward(self, x, attention_mask=None,key_padding_mask=None):
        B, T, C = x.size()

        # Linear projection and reshape
        q = self.q_proj(x).view(B, T, self.num_heads, self.head_dim).transpose(1, 2)
        k = self.k_proj(x).view(B, T, self.num_heads, self.head_dim).transpose(1, 2)
        v = self.v_proj(x).view(B, T, self.num_heads, self.head_dim).transpose(1, 2)

        # Scaled Dot-Product Attention
        scores = torch.matmul(q, k.transpose(-2, -1)) / math.sqrt(self.head_dim)
        if attention_mask is not None:
            scores += attention_mask
        if key_padding_mask is not None:
            key_padding_mask = key_padding_mask.unsqueeze(1).unsqueeze(2)
            scores = scores.masked_fill(key_padding_mask,float('-inf'))
        attn_weights = F.softmax(scores, dim=-1)
        attn_weights = torch.nan_to_num(attn_weights, nan=0.0)
        attn_weights = self.attn_dropout(attn_weights)

        context = torch.matmul(attn_weights, v)  # [B, H, T, D]
        context = context.transpose(1, 2).reshape(B, T, C)
        return context

class BertSelfOutput(nn.Module):
    def __init__(self, hidden_size=512, dropout=0.1):
        super().__init__()
        self.dense = nn.Linear(hidden_size, hidden_size)
        self.dropout = nn.Dropout(dropout)
        self.LayerNorm = nn.LayerNorm(hidden_size)

    def forward(self, hidden_states, input_tensor):
        hidden_states = self.dense(hidden_states)
        hidden_states = self.dropout(hidden_states)
        return self.LayerNorm(hidden_states + input_tensor)

class BertAttention(nn.Module):
    def __init__(self, hidden_size=512, num_heads=8, dropout=0.1):
        super().__init__()
        self.self = BertSdpaSelfAttention(hidden_size, num_heads, dropout)
        self.output = BertSelfOutput(hidden_size, dropout)

    def forward(self, hidden_states, attention_mask=None,key_padding_mask=None):
        self_output = self.self(hidden_states, attention_mask,key_padding_mask)
        return self.output(self_output, hidden_states)

class BertIntermediate(nn.Module):
    def __init__(self, hidden_size=512, intermediate_size=3072):
        super().__init__()
        self.dense = nn.Linear(hidden_size, intermediate_size)
        self.activation = nn.GELU()

    def forward(self, hidden_states):
        return self.activation(self.dense(hidden_states))

class BertOutput(nn.Module):
    def __init__(self, intermediate_size=3072, hidden_size=512, dropout=0.1):
        super().__init__()
        self.dense = nn.Linear(intermediate_size, hidden_size)
        self.dropout = nn.Dropout(dropout)
        self.LayerNorm = nn.LayerNorm(hidden_size)

    def forward(self, hidden_states, input_tensor):
        hidden_states = self.dense(hidden_states)
        hidden_states = self.dropout(hidden_states)
        return self.LayerNorm(hidden_states + input_tensor)

class BertLayer(nn.Module):
    def __init__(self, hidden_size=512, intermediate_size=3072, num_heads=8, dropout=0.1):
        super().__init__()
        self.attention = BertAttention(hidden_size, num_heads, dropout)
        self.intermediate = BertIntermediate(hidden_size, intermediate_size)
        self.output = BertOutput(intermediate_size, hidden_size, dropout)

    def forward(self, hidden_states, attention_mask=None,key_padding_mask=None):
        attention_output = self.attention(hidden_states, attention_mask,key_padding_mask)
        intermediate_output = self.intermediate(attention_output)
        layer_output = self.output(intermediate_output, attention_output)
        return layer_output

# %%
import torch
import torch.nn as nn

class BertEncoder(nn.Module):
    def __init__(self, num_layers=2, hidden_size=512, intermediate_size=3072, num_heads=8, dropout=0.1):
        super().__init__()
        self.layer = nn.ModuleList([
            BertLayer(hidden_size, intermediate_size, num_heads, dropout)
            for _ in range(num_layers)
        ])

    def forward(self, hidden_states, attention_mask=None,key_padding_mask=None):
        for layer_module in self.layer:
            hidden_states = layer_module(hidden_states, attention_mask,key_padding_mask)
        return hidden_states

# %%
import torch
import torch.nn as nn



class BertModel(nn.Module):
    def __init__(self, 
                 vocab_size=30522,
                 hidden_size=512,
                 intermediate_size=3072,
                 num_heads=8,
                 num_layers=2,
                 max_len=512,
                 dropout=0.1):
        super().__init__()
        self.embeddings = BertEmbeddings(vocab_size, hidden_size, max_len, dropout=dropout)
        self.encoder = BertEncoder(num_layers, hidden_size, intermediate_size, num_heads, dropout)
        self.output_layer = nn.Sequential(
           nn.Dropout(dropout),
            nn.Linear(hidden_size, vocab_size)
        )

    def forward(self, input_ids, attention_mask=None,key_padding_mask=None):
        embedding_output = self.embeddings(input_ids)
        encoder_output = self.encoder(embedding_output, attention_mask,key_padding_mask)
        output = self.output_layer(encoder_output)
        return output

# %%
from torchinfo import summary
model = BertModel()
summary(model,depth=6)
# Out:
# ================================================================================
# Layer (type:depth-idx)                                  Param #
# ================================================================================
# BertModel                                               --
# ├─BertEmbeddings: 1-1                                   --
# │    └─Embedding: 2-1                                   15,627,264
# │    └─Embedding: 2-2                                   262,144
# │    └─LayerNorm: 2-3                                   1,024
# │    └─Dropout: 2-4                                     --
# ├─BertEncoder: 1-2                                      --
# │    └─ModuleList: 2-5                                  --
# │    │    └─BertLayer: 3-1                              --
# │    │    │    └─BertAttention: 4-1                     --
# │    │    │    │    └─BertSdpaSelfAttention: 5-1        --
# │    │    │    │    │    └─Linear: 6-1                  262,656
# │    │    │    │    │    └─Linear: 6-2                  262,656
# │    │    │    │    │    └─Linear: 6-3                  262,656
# │    │    │    │    │    └─Dropout: 6-4                 --
# │    │    │    │    └─BertSelfOutput: 5-2               --
# │    │    │    │    │    └─Linear: 6-5                  262,656
# │    │    │    │    │    └─Dropout: 6-6                 --
# │    │    │    │    │    └─LayerNorm: 6-7               1,024
# │    │    │    └─BertIntermediate: 4-2                  --
# │    │    │    │    └─Linear: 5-3                       1,575,936
# │    │    │    │    └─GELU: 5-4                         --
# │    │    │    └─BertOutput: 4-3                        --
# │    │    │    │    └─Linear: 5-5                       1,573,376
# │    │    │    │    └─Dropout: 5-6                      --
# │    │    │    │    └─LayerNorm: 5-7                    1,024
# │    │    └─BertLayer: 3-2                              --
# │    │    │    └─BertAttention: 4-4                     --
# │    │    │    │    └─BertSdpaSelfAttention: 5-8        --
# │    │    │    │    │    └─Linear: 6-8                  262,656
# │    │    │    │    │    └─Linear: 6-9                  262,656
# │    │    │    │    │    └─Linear: 6-10                 262,656
# │    │    │    │    │    └─Dropout: 6-11                --
# │    │    │    │    └─BertSelfOutput: 5-9               --
# │    │    │    │    │    └─Linear: 6-12                 262,656
# │    │    │    │    │    └─Dropout: 6-13                --
# │    │    │    │    │    └─LayerNorm: 6-14              1,024
# │    │    │    └─BertIntermediate: 4-5                  --
# │    │    │    │    └─Linear: 5-10                      1,575,936
# │    │    │    │    └─GELU: 5-11                        --
# │    │    │    └─BertOutput: 4-6                        --
# │    │    │    │    └─Linear: 5-12                      1,573,376
# │    │    │    │    └─Dropout: 5-13                     --
# │    │    │    │    └─LayerNorm: 5-14                   1,024
# ├─Sequential: 1-3                                       --
# │    └─Dropout: 2-6                                     --
# │    └─Linear: 2-7                                      15,657,786
# ================================================================================
# Total params: 39,952,186
# Trainable params: 39,952,186
# Non-trainable params: 0
# ================================================================================

# %%
def hit_ratio(ground_truth:list,prediction:list,k:int):
    hits = 0
    total = len(ground_truth)
    for i, (gt_item, pred) in enumerate(zip(ground_truth, prediction)):
        
        if gt_item in pred[:k]:
            print(f"[Sample {i}] GT: {gt_item}, Pred top-{k}: {pred[:k]}")
            hits += 1
    return hits / total

# -------------------------
def evaluate_model(model, val_item_sequences, k=10):
    model.eval()
    device = 'mps'

    ground_truths = []
    predictions = []

    with torch.no_grad():
        for user, seq in val_item_sequences.items():
            item_seq = seq['item_id']
            


            # Prepare input and target
            input_items = item_seq[:-1]
            
            target_item = item_seq[-1]

            # Use your own padding utility to ensure correct length
            padded_seq, _ = padding(
                mask_seq={user: {'item_id': input_items}},
                labels={user: []},  # empty labels not needed here
                max_len=max_len
            )
            
            padded_items = padded_seq[user]['item_id']
            # padded_topics = padded_seq[user]['Topic']

            item_tensor = torch.tensor([padded_items], dtype=torch.long).to(device)
            
            key_padding_mask = (item_tensor == 0)

            logits = model(item_tensor, key_padding_mask=key_padding_mask)[:,min(len(item_seq)-1,max_len-1),:]
            probabilities = torch.softmax(logits, dim=-1)
            # print(probabilities.size())
            
            

            topk = torch.topk(probabilities, k=k).indices[0].tolist()
            # print(topk)
            ground_truths.append(index_to_item[target_item])
            predictions.append([index_to_item[i] for i in topk])

            # print(ground_truths)
            # print(predictions)
    return hit_ratio(ground_truths, predictions, k)

# %%
import torch.optim as optim
from tqdm import tqdm
import os 
def train_model(train_users,val_users,fold_num):
    train_user_item_to_index_sequence = {user: seq for user, seq in user_item_to_index_sequence.items() if user in train_users}
    mask_seq , labels = mask_sequence(train_user_item_to_index_sequence,mask_ratio=0.6)
    padded_mask_seq,padded_labels = padding(mask_seq,labels,max_len=max_len)

    tensor_item_ids = torch.stack([
        torch.tensor(user_seq['item_id']) for user_seq in padded_mask_seq.values()
    ])



    tensor_labels = torch.stack([
        torch.tensor(seq) for seq in padded_labels.values()
        ])
        
    train_dataset = torch.utils.data.TensorDataset(
        tensor_item_ids,

        tensor_labels
    )
    train_dataloader = torch.utils.data.DataLoader(train_dataset,batch_size=64,shuffle=True)


    # train model 
    device = 'mps'
    model = BertModel(vocab_size=len(unique_item_id)+1,hidden_size=256,intermediate_size=256*12,num_heads=4,num_layers=2,max_len=50).to(device)
    optimizer = optim.AdamW(model.parameters(), lr=0.001)
    criterion = torch.nn.CrossEntropyLoss(ignore_index=-100)
    best_hr = 0
    for epoch in range(5):
        model.train()
        epoch_loss = 0
        for batch in tqdm(train_dataloader,desc=f"Fold {fold_num} Epoch {epoch+1}", unit="batch"):
            item_ids  , labels = batch
            item_ids  , labels = item_ids.to(device) , labels.to(device)
            key_padding_mask = (item_ids == 0)
            
            optimizer.zero_grad()
            outputs = model(item_ids,key_padding_mask=key_padding_mask)
            # print(outputs.size()
            loss = criterion(outputs.view(-1, len(unique_item_id)+1), labels.view(-1))
            loss.backward()
            torch.mps.empty_cache()
            optimizer.step()
            # print(loss.item())
            epoch_loss += loss.item()
        print(f"Epoch {epoch+1}, Loss {epoch_loss}")
        # evaluate model
        model.eval()
        # val_user_item_sequences = {user: seq for user, seq in user_item_sequence.items() if user in val_users}
        val_item_sequences = {user: seq for user, seq in user_item_to_index_sequence.items() if user in val_users}
        val_hr = evaluate_model(model, val_item_sequences,k=5)
        print(f"Fold {fold_num} Epoch {epoch+1}, Validation HR@5: {val_hr}")
        if val_hr > best_hr:
            best_hr = val_hr
            save_path = f"models/models_item_with_bert/fold_{fold_num}"
            os.makedirs(save_path, exist_ok=True)
            torch.save(model.state_dict(), f"{save_path}/best_model.pth")
    return model, best_hr

# %%
from sklearn.model_selection import KFold
set_seed()
kf = KFold(n_splits=5,shuffle=True,random_state=42)
user_list = list(user_item_sequence.keys())
fold_results = {}
for fold_num , (train_idx,val_idx) in enumerate(kf.split(user_list),1):
    print(f"\nStarting Fold {fold_num}...")
    train_users = [user_list[i] for i in train_idx]
    val_users = [user_list[i] for i in val_idx]
    model,val_hr =  train_model(train_users, val_users, fold_num)
    fold_results[fold_num] = val_hr
    save_path = f"results/results_item_with_bert/fold_{fold_num}"
    os.makedirs(save_path, exist_ok=True)
    with open(f"{save_path}/results.txt", "w") as f:
        f.write(f"Validation HR@5: {val_hr}\n")
    del model
    torch.mps.empty_cache()
with open("results/results_item_with_bert/overall_results.txt", "w") as f:
    for fold, hr in fold_results.items():
        f.write(f"Fold {fold}: HR@5 = {hr}\n")
    mean_hr = sum(fold_results.values()) / len(fold_results)
    f.write(f"\nMean HR@5 across folds: {mean_hr}")
# Out:
# Starting Fold 1...
# Fold 1 Epoch 1: 100%|██████████| 422/422 [00:55<00:00,  7.66batch/s]
# Epoch 1, Loss 3441.252510547638
# tensor([4.8326e-06, 2.5498e-05, 4.4195e-06], device='mps:0')
# tensor([7.5610e-06, 3.5416e-05, 5.8640e-06], device='mps:0')
# tensor([1.1661e-05, 4.8565e-05, 8.0376e-06], device='mps:0')
# tensor([2.8864e-05, 8.1484e-05, 1.3734e-05], device='mps:0')
# tensor([7.0509e-05, 1.2634e-04, 2.4786e-05], device='mps:0')
# tensor([2.5087e-05, 7.5033e-05, 1.2713e-05], device='mps:0')
# tensor([1.2058e-05, 4.8681e-05, 7.9998e-06], device='mps:0')
# tensor([3.9164e-06, 2.1560e-05, 3.9055e-06], device='mps:0')
# tensor([9.3952e-06, 4.2089e-05, 6.9015e-06], device='mps:0')
# tensor([7.3275e-05, 1.2398e-04, 2.4464e-05], device='mps:0')
# tensor([3.9164e-06, 2.1560e-05, 3.9055e-06], device='mps:0')
# tensor([4.2166e-05, 9.8981e-05, 1.7599e-05], device='mps:0')
# tensor([3.5450e-06, 1.9705e-05, 3.5997e-06], device='mps:0')
# tensor([1.1598e-05, 4.8444e-05, 8.0372e-06], device='mps:0')
# tensor([1.3108e-05, 5.0882e-05, 8.1754e-06], device='mps:0')
# tensor([1.2145e-05, 4.8885e-05, 8.1009e-06], device='mps:0')
# tensor([9.7055e-06, 4.2014e-05, 6.9291e-06], device='mps:0')
# tensor([2.1119e-05, 6.9065e-05, 1.1678e-05], device='mps:0')
# tensor([5.7165e-06, 2.9181e-05, 4.9838e-06], device='mps:0')
# tensor([7.7526e-06, 3.6767e-05, 6.0582e-06], device='mps:0')
# tensor([1.6618e-05, 5.9343e-05, 9.6421e-06], device='mps:0')
# tensor([2.7137e-06, 1.5774e-05, 3.1495e-06], device='mps:0')
# tensor([5.9903e-06, 3.0426e-05, 5.1492e-06], device='mps:0')
# tensor([9.7415e-06, 4.3173e-05, 7.1427e-06], device='mps:0')
# tensor([2.7498e-06, 1.5865e-05, 3.1203e-06], device='mps:0')
# tensor([4.7922e-06, 2.5276e-05, 4.3888e-06], device='mps:0')
# tensor([9.7488e-06, 4.3243e-05, 7.0782e-06], device='mps:0')
# tensor([7.2788e-06, 3.4482e-05, 5.7462e-06], device='mps:0')
# tensor([1.0424e-05, 4.4671e-05, 7.3124e-06], device='mps:0')
# tensor([1.0435e-05, 4.4999e-05, 7.3943e-06], device='mps:0')
# tensor([4.6585e-06, 2.4731e-05, 4.3037e-06], device='mps:0')
# tensor([5.4343e-06, 2.7554e-05, 4.6615e-06], device='mps:0')
# tensor([6.5031e-06, 3.1630e-05, 5.3146e-06], device='mps:0')
# tensor([8.6095e-06, 3.8876e-05, 6.3947e-06], device='mps:0')
# tensor([1.9146e-05, 6.5110e-05, 1.0982e-05], device='mps:0')
# tensor([6.1886e-05, 1.1465e-04, 2.1859e-05], device='mps:0')
# tensor([8.0596e-06, 3.7739e-05, 6.2335e-06], device='mps:0')
# tensor([1.1305e-05, 4.7579e-05, 7.8642e-06], device='mps:0')
# tensor([5.8834e-06, 2.9857e-05, 5.0639e-06], device='mps:0')
# tensor([3.0697e-05, 8.3541e-05, 1.4435e-05], device='mps:0')
# tensor([1.5768e-05, 5.7677e-05, 9.6762e-06], device='mps:0')
# tensor([6.8336e-06, 3.3457e-05, 5.5596e-06], device='mps:0')
# tensor([7.6672e-06, 3.6191e-05, 5.9833e-06], device='mps:0')
# tensor([4.0749e-06, 2.2463e-05, 4.0612e-06], device='mps:0')
# tensor([7.3551e-06, 3.5177e-05, 5.8402e-06], device='mps:0')
# tensor([1.1295e-05, 4.7546e-05, 7.7986e-06], device='mps:0')
# tensor([9.4022e-06, 4.2318e-05, 6.9963e-06], device='mps:0')
# tensor([1.3413e-05, 5.2774e-05, 8.7250e-06], device='mps:0')
# tensor([6.1832e-06, 3.1250e-05, 5.2691e-06], device='mps:0')
# tensor([8.0845e-06, 3.7115e-05, 6.2049e-06], device='mps:0')
# tensor([4.6533e-06, 2.4896e-05, 4.3606e-06], device='mps:0')
# tensor([1.5319e-05, 5.6272e-05, 9.3459e-06], device='mps:0')
# tensor([1.4579e-05, 5.5507e-05, 9.2518e-06], device='mps:0')
# tensor([4.9517e-05, 1.0738e-04, 1.9668e-05], device='mps:0')
# tensor([4.6905e-06, 2.5038e-05, 4.3548e-06], device='mps:0')
# tensor([6.5163e-05, 1.2165e-04, 2.3350e-05], device='mps:0')
# tensor([5.5875e-06, 2.8694e-05, 4.8591e-06], device='mps:0')
# tensor([1.8920e-05, 6.3663e-05, 1.0778e-05], device='mps:0')
# tensor([7.4205e-06, 3.5008e-05, 5.8326e-06], device='mps:0')
# tensor([5.6268e-05, 1.0807e-04, 1.9768e-05], device='mps:0')
# tensor([4.8123e-05, 1.0558e-04, 1.9113e-05], device='mps:0')
# tensor([3.0001e-05, 8.2417e-05, 1.4260e-05], device='mps:0')
# tensor([5.2981e-05, 1.1048e-04, 2.0408e-05], device='mps:0')
# tensor([8.5667e-06, 3.9374e-05, 6.5253e-06], device='mps:0')
# tensor([2.0941e-05, 6.8133e-05, 1.1545e-05], device='mps:0')
# tensor([3.3652e-05, 8.8131e-05, 1.5177e-05], device='mps:0')
# tensor([5.7148e-05, 1.0991e-04, 2.0541e-05], device='mps:0')
# tensor([5.6118e-06, 2.8650e-05, 4.8770e-06], device='mps:0')
# tensor([1.2296e-05, 5.0122e-05, 8.2954e-06], device='mps:0')
# tensor([5.7143e-06, 2.8675e-05, 4.8868e-06], device='mps:0')
# tensor([2.2860e-05, 7.1438e-05, 1.1885e-05], device='mps:0')
# tensor([9.7407e-05, 1.3534e-04, 2.8803e-05], device='mps:0')
# tensor([6.2303e-06, 3.0760e-05, 5.2071e-06], device='mps:0')
# tensor([4.0668e-06, 2.2105e-05, 3.9627e-06], device='mps:0')
# tensor([9.6685e-06, 4.2062e-05, 6.9220e-06], device='mps:0')
# tensor([5.1646e-06, 2.6994e-05, 4.6481e-06], device='mps:0')
# tensor([9.2221e-06, 4.1661e-05, 6.8662e-06], device='mps:0')
# tensor([8.6805e-06, 3.9948e-05, 6.5663e-06], device='mps:0')
# tensor([5.5477e-05, 1.1260e-04, 2.0826e-05], device='mps:0')
# tensor([1.8503e-05, 6.2811e-05, 1.0613e-05], device='mps:0')
# tensor([1.1628e-05, 4.7508e-05, 7.8112e-06], device='mps:0')
# tensor([5.3889e-05, 1.1107e-04, 2.0552e-05], device='mps:0')
# tensor([1.1941e-05, 4.9159e-05, 8.0659e-06], device='mps:0')
# tensor([5.7114e-06, 2.9272e-05, 4.9602e-06], device='mps:0')
# tensor([7.5888e-06, 3.6106e-05, 5.9728e-06], device='mps:0')
# tensor([2.7137e-06, 1.5774e-05, 3.1495e-06], device='mps:0')
# tensor([8.3205e-06, 3.8752e-05, 6.3753e-06], device='mps:0')
# tensor([1.7834e-05, 6.1446e-05, 1.0361e-05], device='mps:0')
# tensor([3.6590e-05, 9.2012e-05, 1.5933e-05], device='mps:0')
# tensor([9.6401e-06, 4.2523e-05, 6.9708e-06], device='mps:0')
# tensor([1.0905e-05, 4.6447e-05, 7.6156e-06], device='mps:0')
# tensor([9.2127e-06, 4.0706e-05, 6.7260e-06], device='mps:0')
# tensor([1.3326e-05, 5.2610e-05, 8.6660e-06], device='mps:0')
# tensor([2.2952e-05, 7.1247e-05, 1.1928e-05], device='mps:0')
# tensor([1.2745e-05, 5.1210e-05, 8.4396e-06], device='mps:0')
# tensor([9.6976e-06, 4.3182e-05, 7.1380e-06], device='mps:0')
# tensor([3.6775e-06, 2.0429e-05, 3.7524e-06], device='mps:0')
# tensor([5.0493e-06, 2.6441e-05, 4.5527e-06], device='mps:0')
# tensor([1.6449e-05, 5.8906e-05, 9.9016e-06], device='mps:0')
# tensor([1.0959e-05, 4.6564e-05, 7.6459e-06], device='mps:0')
# tensor([4.5544e-05, 1.0258e-04, 1.8469e-05], device='mps:0')
# tensor([1.1480e-05, 4.8074e-05, 7.9079e-06], device='mps:0')
# tensor([5.3485e-05, 1.1126e-04, 2.0445e-05], device='mps:0')
# tensor([8.2101e-06, 3.8219e-05, 6.3166e-06], device='mps:0')
# tensor([3.2236e-06, 1.8186e-05, 3.3866e-06], device='mps:0')
# tensor([7.6885e-06, 3.5714e-05, 5.9190e-06], device='mps:0')
# tensor([9.2886e-06, 4.1697e-05, 6.8596e-06], device='mps:0')
# tensor([5.4538e-06, 2.8197e-05, 4.8274e-06], device='mps:0')
# tensor([1.9746e-05, 6.6347e-05, 1.1210e-05], device='mps:0')
# tensor([4.7317e-05, 1.0532e-04, 1.8786e-05], device='mps:0')
# tensor([4.1814e-05, 9.8982e-05, 1.7312e-05], device='mps:0')
# tensor([4.5395e-05, 1.0245e-04, 1.8418e-05], device='mps:0')
# tensor([1.0423e-05, 4.5147e-05, 7.4485e-06], device='mps:0')
# tensor([6.0092e-06, 2.9709e-05, 5.0501e-06], device='mps:0')
# tensor([1.5693e-05, 5.7933e-05, 9.6645e-06], device='mps:0')
# tensor([7.2008e-05, 1.2536e-04, 2.4591e-05], device='mps:0')
# tensor([7.8752e-06, 3.7186e-05, 6.1761e-06], device='mps:0')
# tensor([1.1396e-05, 4.7662e-05, 7.8262e-06], device='mps:0')
# tensor([3.9406e-05, 9.6299e-05, 1.6982e-05], device='mps:0')
# tensor([9.9061e-06, 4.3535e-05, 7.1348e-06], device='mps:0')
# tensor([5.7597e-06, 2.9328e-05, 4.9629e-06], device='mps:0')
# tensor([1.3212e-05, 5.2291e-05, 8.6197e-06], device='mps:0')
# tensor([1.2540e-05, 5.0770e-05, 8.3876e-06], device='mps:0')
# tensor([2.5291e-05, 7.5377e-05, 1.2774e-05], device='mps:0')
# tensor([3.2192e-05, 8.5425e-05, 1.4780e-05], device='mps:0')
# tensor([2.2676e-05, 7.1653e-05, 1.2169e-05], device='mps:0')
# tensor([9.0708e-06, 4.1173e-05, 6.7424e-06], device='mps:0')
# tensor([3.3309e-06, 1.8722e-05, 3.5150e-06], device='mps:0')
# tensor([1.5652e-05, 5.7106e-05, 9.5716e-06], device='mps:0')
# tensor([4.2718e-05, 9.8691e-05, 1.7788e-05], device='mps:0')
# tensor([6.7582e-05, 1.2080e-04, 2.3000e-05], device='mps:0')
# tensor([7.7483e-06, 3.6735e-05, 6.0731e-06], device='mps:0')
# tensor([3.8501e-05, 9.4483e-05, 1.6577e-05], device='mps:0')
# tensor([3.6775e-06, 2.0429e-05, 3.7524e-06], device='mps:0')
# tensor([8.9239e-06, 4.0799e-05, 6.7074e-06], device='mps:0')
# tensor([1.3183e-05, 5.2355e-05, 8.7045e-06], device='mps:0')
# tensor([1.7918e-05, 6.1738e-05, 1.0396e-05], device='mps:0')
# tensor([1.1374e-05, 4.7933e-05, 7.9250e-06], device='mps:0')
# tensor([9.9239e-06, 4.3715e-05, 7.1847e-06], device='mps:0')
# tensor([9.9080e-06, 4.3537e-05, 7.1335e-06], device='mps:0')
# tensor([1.0149e-05, 4.4233e-05, 7.2439e-06], device='mps:0')
# tensor([6.3388e-06, 3.1292e-05, 5.2605e-06], device='mps:0')
# tensor([3.2683e-05, 8.6142e-05, 1.5063e-05], device='mps:0')
# tensor([3.3357e-05, 8.8823e-05, 1.5198e-05], device='mps:0')
# tensor([6.1303e-06, 3.0706e-05, 5.1327e-06], device='mps:0')
# tensor([1.1369e-05, 4.7690e-05, 7.8426e-06], device='mps:0')
# tensor([9.6681e-06, 4.2783e-05, 7.0401e-06], device='mps:0')
# tensor([1.5179e-05, 5.7173e-05, 9.5237e-06], device='mps:0')
# tensor([1.5064e-05, 5.6716e-05, 9.4121e-06], device='mps:0')
# tensor([7.6544e-05, 1.2921e-04, 2.6021e-05], device='mps:0')
# tensor([6.0988e-06, 3.0243e-05, 5.1300e-06], device='mps:0')
# tensor([2.7137e-06, 1.5774e-05, 3.1495e-06], device='mps:0')
# tensor([1.1631e-05, 4.8517e-05, 7.9966e-06], device='mps:0')
# tensor([5.4711e-05, 1.0820e-04, 2.0008e-05], device='mps:0')
# tensor([3.9164e-06, 2.1560e-05, 3.9055e-06], device='mps:0')
# tensor([4.9498e-06, 2.6237e-05, 4.5351e-06], device='mps:0')
# tensor([1.1588e-05, 4.7777e-05, 7.8570e-06], device='mps:0')
# tensor([4.7420e-06, 2.5142e-05, 4.3444e-06], device='mps:0')
# tensor([4.6190e-06, 2.4542e-05, 4.2975e-06], device='mps:0')
# tensor([2.5407e-05, 7.5511e-05, 1.2779e-05], device='mps:0')
# tensor([3.9164e-06, 2.1560e-05, 3.9055e-06], device='mps:0')
# tensor([2.0918e-05, 6.8530e-05, 1.1584e-05], device='mps:0')
# tensor([9.9014e-06, 4.3562e-05, 7.1443e-06], device='mps:0')
# tensor([1.1636e-05, 4.8514e-05, 7.9888e-06], device='mps:0')
# tensor([1.4093e-05, 5.4247e-05, 8.9808e-06], device='mps:0')
# tensor([1.0435e-05, 4.4999e-05, 7.3943e-06], device='mps:0')
# tensor([2.0173e-05, 6.6419e-05, 1.0997e-05], device='mps:0')
# tensor([5.2805e-05, 1.1028e-04, 2.0210e-05], device='mps:0')
# tensor([9.6496e-06, 4.3100e-05, 7.0790e-06], device='mps:0')
# tensor([1.8834e-05, 6.4539e-05, 1.0858e-05], device='mps:0')
# tensor([8.3736e-05, 1.3191e-04, 2.7319e-05], device='mps:0')
# tensor([3.1324e-05, 8.5406e-05, 1.4825e-05], device='mps:0')
# tensor([1.0549e-05, 4.5685e-05, 7.5546e-06], device='mps:0')
# tensor([6.1630e-06, 3.0870e-05, 5.1414e-06], device='mps:0')
# tensor([2.5401e-05, 7.5038e-05, 1.2984e-05], device='mps:0')
# tensor([1.1941e-05, 4.9159e-05, 8.0659e-06], device='mps:0')
# tensor([4.6918e-06, 2.5000e-05, 4.3882e-06], device='mps:0')
# tensor([7.3032e-06, 3.5220e-05, 5.8533e-06], device='mps:0')
# tensor([7.9097e-06, 3.7489e-05, 6.1800e-06], device='mps:0')
# tensor([1.1633e-05, 4.7442e-05, 7.8168e-06], device='mps:0')
# tensor([3.8130e-05, 9.3428e-05, 1.6646e-05], device='mps:0')
# tensor([1.0847e-05, 4.6285e-05, 7.6112e-06], device='mps:0')
# tensor([1.3387e-05, 5.2171e-05, 8.6167e-06], device='mps:0')
# tensor([1.6247e-05, 5.8125e-05, 9.7678e-06], device='mps:0')
# tensor([5.7165e-06, 2.9181e-05, 4.9838e-06], device='mps:0')
# tensor([1.5410e-05, 5.6713e-05, 9.3851e-06], device='mps:0')
# tensor([1.1599e-05, 4.8439e-05, 7.9696e-06], device='mps:0')
# tensor([1.5210e-05, 5.6234e-05, 9.3872e-06], device='mps:0')
# tensor([4.8332e-06, 2.5483e-05, 4.4001e-06], device='mps:0')
# tensor([1.6613e-05, 5.9030e-05, 9.7999e-06], device='mps:0')
# tensor([3.9164e-06, 2.1560e-05, 3.9055e-06], device='mps:0')
# tensor([3.3094e-05, 8.6663e-05, 1.5110e-05], device='mps:0')
# tensor([4.9452e-06, 2.6091e-05, 4.5085e-06], device='mps:0')
# tensor([2.1142e-05, 6.8198e-05, 1.1647e-05], device='mps:0')
# tensor([1.0573e-05, 4.4721e-05, 7.3556e-06], device='mps:0')
# tensor([1.1149e-05, 4.6326e-05, 7.5981e-06], device='mps:0')
# tensor([3.2221e-05, 8.5493e-05, 1.4898e-05], device='mps:0')
# tensor([1.2942e-05, 5.1646e-05, 8.5080e-06], device='mps:0')
# tensor([9.0565e-06, 4.0926e-05, 6.6909e-06], device='mps:0')
# tensor([8.2002e-06, 3.7568e-05, 6.1921e-06], device='mps:0')
# tensor([5.8871e-06, 2.9966e-05, 5.0494e-06], device='mps:0')
# tensor([3.7142e-05, 9.2605e-05, 1.6112e-05], device='mps:0')
# tensor([5.1646e-06, 2.6994e-05, 4.6481e-06], device='mps:0')
# tensor([4.7390e-06, 2.5140e-05, 4.3651e-06], device='mps:0')
# tensor([8.3339e-06, 3.8732e-05, 6.3865e-06], device='mps:0')
# tensor([5.4365e-06, 2.7823e-05, 4.7831e-06], device='mps:0')
# tensor([7.4514e-06, 3.5735e-05, 5.9124e-06], device='mps:0')
# tensor([2.6956e-06, 1.5454e-05, 3.0829e-06], device='mps:0')
# tensor([1.3849e-05, 5.3795e-05, 8.9085e-06], device='mps:0')
# tensor([2.2205e-06, 1.2916e-05, 2.7385e-06], device='mps:0')
# tensor([3.3553e-05, 8.7638e-05, 1.5342e-05], device='mps:0')
# tensor([8.0835e-05, 1.2874e-04, 2.5857e-05], device='mps:0')
# tensor([3.7886e-05, 9.4116e-05, 1.6410e-05], device='mps:0')
# tensor([3.8526e-06, 2.1187e-05, 3.8301e-06], device='mps:0')
# tensor([9.6496e-06, 4.3100e-05, 7.0790e-06], device='mps:0')
# tensor([4.6611e-05, 1.0351e-04, 1.8711e-05], device='mps:0')
# tensor([1.2802e-05, 5.1101e-05, 8.4491e-06], device='mps:0')
# tensor([3.9154e-05, 9.5211e-05, 1.6481e-05], device='mps:0')
# tensor([7.1949e-06, 3.4878e-05, 5.7730e-06], device='mps:0')
# tensor([1.2176e-05, 4.8909e-05, 8.0378e-06], device='mps:0')
# tensor([1.2405e-05, 5.0211e-05, 8.2576e-06], device='mps:0')
# tensor([8.9239e-06, 4.0799e-05, 6.7074e-06], device='mps:0')
# tensor([7.0546e-06, 3.4242e-05, 5.6865e-06], device='mps:0')
# tensor([2.3300e-05, 7.1942e-05, 1.2130e-05], device='mps:0')
# tensor([2.7137e-06, 1.5774e-05, 3.1495e-06], device='mps:0')
# tensor([1.6040e-05, 5.8833e-05, 9.8090e-06], device='mps:0')
# tensor([1.7211e-05, 6.1227e-05, 1.0271e-05], device='mps:0')
# tensor([3.6639e-05, 9.2329e-05, 1.6047e-05], device='mps:0')
# tensor([5.9832e-05, 1.1308e-04, 2.1311e-05], device='mps:0')
# tensor([3.6561e-05, 9.1243e-05, 1.6204e-05], device='mps:0')
# tensor([6.1811e-05, 1.1921e-04, 2.2661e-05], device='mps:0')
# tensor([6.1805e-05, 1.1493e-04, 2.1836e-05], device='mps:0')
# tensor([1.1424e-05, 4.7860e-05, 7.8983e-06], device='mps:0')
# tensor([3.2465e-05, 8.5730e-05, 1.4890e-05], device='mps:0')
# tensor([5.0027e-05, 1.0661e-04, 1.9284e-05], device='mps:0')
# tensor([3.7436e-06, 2.0641e-05, 3.7581e-06], device='mps:0')
# tensor([6.7966e-05, 1.2189e-04, 2.3927e-05], device='mps:0')
# tensor([5.3033e-06, 2.6957e-05, 4.5914e-06], device='mps:0')
# tensor([7.9677e-06, 3.6936e-05, 6.1528e-06], device='mps:0')
# tensor([7.5350e-06, 3.5976e-05, 5.9732e-06], device='mps:0')
# tensor([1.2893e-05, 5.1597e-05, 8.4937e-06], device='mps:0')
# tensor([5.5390e-06, 2.8200e-05, 4.8326e-06], device='mps:0')
# tensor([5.2584e-05, 1.0518e-04, 1.9218e-05], device='mps:0')
# tensor([5.1646e-06, 2.6994e-05, 4.6481e-06], device='mps:0')
# tensor([9.2366e-05, 1.3485e-04, 2.8170e-05], device='mps:0')
# tensor([2.4624e-05, 7.4546e-05, 1.2630e-05], device='mps:0')
# tensor([1.6815e-05, 6.0505e-05, 1.0124e-05], device='mps:0')
# tensor([9.4838e-05, 1.3683e-04, 2.8710e-05], device='mps:0')
# tensor([3.5450e-06, 1.9705e-05, 3.5997e-06], device='mps:0')
# tensor([6.5483e-06, 3.1825e-05, 5.3687e-06], device='mps:0')
# tensor([1.2716e-05, 5.1321e-05, 8.4743e-06], device='mps:0')
# tensor([7.7065e-06, 3.6607e-05, 6.0819e-06], device='mps:0')
# tensor([7.6065e-06, 3.5636e-05, 5.9205e-06], device='mps:0')
# tensor([5.9092e-05, 1.1579e-04, 2.1793e-05], device='mps:0')
# tensor([7.3581e-06, 3.5339e-05, 5.8786e-06], device='mps:0')
# tensor([1.0459e-05, 4.4429e-05, 7.2683e-06], device='mps:0')
# tensor([1.1786e-05, 4.8806e-05, 8.0160e-06], device='mps:0')
# tensor([1.0453e-05, 4.5165e-05, 7.4054e-06], device='mps:0')
# tensor([9.4501e-06, 4.2269e-05, 6.9533e-06], device='mps:0')
# tensor([9.5208e-05, 1.3753e-04, 2.9036e-05], device='mps:0')
# tensor([8.0388e-05, 1.2857e-04, 2.6157e-05], device='mps:0')
# tensor([1.2590e-05, 5.1056e-05, 8.4616e-06], device='mps:0')
# tensor([5.0883e-06, 2.6742e-05, 4.6237e-06], device='mps:0')
# tensor([1.4063e-05, 5.4301e-05, 8.9762e-06], device='mps:0')
# tensor([1.7490e-05, 6.1665e-05, 1.0345e-05], device='mps:0')
# tensor([6.2349e-05, 1.1436e-04, 2.1677e-05], device='mps:0')
# tensor([1.4672e-05, 5.5932e-05, 9.2886e-06], device='mps:0')
# tensor([4.8785e-06, 2.5914e-05, 4.5022e-06], device='mps:0')
# tensor([1.1257e-05, 4.6949e-05, 7.6571e-06], device='mps:0')
# tensor([9.6976e-06, 4.3182e-05, 7.1380e-06], device='mps:0')
# tensor([6.2269e-06, 3.0696e-05, 5.1822e-06], device='mps:0')
# tensor([6.7050e-05, 1.1864e-04, 2.3000e-05], device='mps:0')
# tensor([6.8054e-06, 3.3506e-05, 5.6243e-06], device='mps:0')
# tensor([1.6024e-05, 5.8756e-05, 9.7820e-06], device='mps:0')
# tensor([4.0668e-06, 2.2105e-05, 3.9627e-06], device='mps:0')
# tensor([1.5270e-05, 5.6414e-05, 9.4139e-06], device='mps:0')
# tensor([4.8332e-06, 2.5483e-05, 4.4001e-06], device='mps:0')
# tensor([4.5129e-06, 2.4230e-05, 4.2412e-06], device='mps:0')
# tensor([1.2214e-05, 5.0057e-05, 8.2841e-06], device='mps:0')
# tensor([1.7109e-05, 6.0646e-05, 1.0135e-05], device='mps:0')
# tensor([2.5059e-05, 7.5281e-05, 1.2703e-05], device='mps:0')
# tensor([9.6065e-06, 4.2816e-05, 7.0408e-06], device='mps:0')
# tensor([5.7443e-05, 1.0997e-04, 2.0477e-05], device='mps:0')
# tensor([2.4924e-05, 7.4389e-05, 1.2558e-05], device='mps:0')
# tensor([4.2570e-06, 2.3034e-05, 4.0593e-06], device='mps:0')
# tensor([6.5762e-06, 3.2426e-05, 5.4507e-06], device='mps:0')
# tensor([2.1965e-05, 7.0156e-05, 1.1928e-05], device='mps:0')
# tensor([1.0996e-05, 4.6063e-05, 7.5349e-06], device='mps:0')
# tensor([2.4688e-05, 7.4073e-05, 1.2534e-05], device='mps:0')
# tensor([4.0888e-06, 2.2301e-05, 3.9993e-06], device='mps:0')
# tensor([6.7971e-06, 3.3296e-05, 5.5391e-06], device='mps:0')
# tensor([9.1971e-06, 4.1373e-05, 6.8095e-06], device='mps:0')
# tensor([1.7171e-05, 6.0923e-05, 1.0192e-05], device='mps:0')
# tensor([6.4396e-06, 3.1916e-05, 5.3043e-06], device='mps:0')
# tensor([1.3821e-05, 5.2995e-05, 8.8085e-06], device='mps:0')
# tensor([2.2892e-05, 7.1528e-05, 1.1946e-05], device='mps:0')
# tensor([1.3077e-05, 5.1301e-05, 8.5000e-06], device='mps:0')
# tensor([1.1368e-05, 4.7907e-05, 7.8999e-06], device='mps:0')
# tensor([1.0687e-05, 4.5213e-05, 7.4518e-06], device='mps:0')
# tensor([7.0546e-06, 3.4242e-05, 5.6865e-06], device='mps:0')
# tensor([8.5315e-06, 3.8705e-05, 6.4051e-06], device='mps:0')
# tensor([1.4324e-05, 5.4318e-05, 8.9800e-06], device='mps:0')
# tensor([3.1968e-05, 8.5023e-05, 1.4842e-05], device='mps:0')
# tensor([1.9893e-05, 6.5631e-05, 1.1134e-05], device='mps:0')
# tensor([7.1290e-05, 1.2157e-04, 2.3982e-05], device='mps:0')
# tensor([1.3515e-05, 5.2245e-05, 8.5538e-06], device='mps:0')
# tensor([1.8794e-05, 6.4019e-05, 1.0531e-05], device='mps:0')
# tensor([6.2420e-06, 3.1226e-05, 5.2855e-06], device='mps:0')
# tensor([7.9294e-06, 3.7365e-05, 6.1920e-06], device='mps:0')
# tensor([1.5629e-05, 5.7998e-05, 9.7075e-06], device='mps:0')
# tensor([9.7425e-05, 1.4128e-04, 3.0370e-05], device='mps:0')
# tensor([4.5728e-06, 2.4540e-05, 4.3288e-06], device='mps:0')
# tensor([6.1832e-06, 3.1250e-05, 5.2691e-06], device='mps:0')
# tensor([1.5028e-05, 5.6875e-05, 9.4646e-06], device='mps:0')
# tensor([1.5267e-05, 5.6321e-05, 9.3664e-06], device='mps:0')
# tensor([8.0226e-06, 3.7044e-05, 6.1285e-06], device='mps:0')
# tensor([4.4452e-05, 1.0259e-04, 1.8239e-05], device='mps:0')
# tensor([2.7137e-06, 1.5774e-05, 3.1495e-06], device='mps:0')
# tensor([5.0241e-05, 1.0176e-04, 1.8155e-05], device='mps:0')
# tensor([1.2296e-05, 5.0122e-05, 8.2954e-06], device='mps:0')
# tensor([1.3303e-05, 5.2685e-05, 8.6864e-06], device='mps:0')
# tensor([1.9546e-05, 6.5280e-05, 1.0771e-05], device='mps:0')
# tensor([1.3544e-05, 5.3212e-05, 8.8074e-06], device='mps:0')
# tensor([2.2572e-05, 7.1294e-05, 1.2150e-05], device='mps:0')
# tensor([8.0430e-06, 3.7129e-05, 6.1852e-06], device='mps:0')
# tensor([2.6764e-05, 7.7522e-05, 1.3239e-05], device='mps:0')
# tensor([1.2288e-05, 4.9176e-05, 8.1106e-06], device='mps:0')
# tensor([7.5888e-06, 3.6106e-05, 5.9728e-06], device='mps:0')
# tensor([4.0335e-05, 9.6193e-05, 1.6972e-05], device='mps:0')
# tensor([7.5658e-06, 3.6286e-05, 6.0162e-06], device='mps:0')
# tensor([3.8275e-05, 9.4554e-05, 1.6611e-05], device='mps:0')
# tensor([1.9741e-05, 6.5474e-05, 1.1116e-05], device='mps:0')
# tensor([1.3912e-05, 5.4080e-05, 8.9687e-06], device='mps:0')
# tensor([2.3555e-05, 7.2399e-05, 1.2197e-05], device='mps:0')
# tensor([1.6982e-05, 6.0188e-05, 1.0089e-05], device='mps:0')
# tensor([8.6181e-05, 1.3357e-04, 2.7380e-05], device='mps:0')
# tensor([7.0489e-06, 3.3572e-05, 5.6422e-06], device='mps:0')
# tensor([9.3569e-06, 4.1832e-05, 6.8889e-06], device='mps:0')
# tensor([1.0160e-05, 4.4316e-05, 7.2410e-06], device='mps:0')
# tensor([1.4714e-05, 5.4838e-05, 9.1131e-06], device='mps:0')
# tensor([9.4633e-06, 4.2327e-05, 6.9549e-06], device='mps:0')
# tensor([7.9577e-05, 1.2940e-04, 2.6274e-05], device='mps:0')
# tensor([4.2241e-06, 2.2620e-05, 3.9992e-06], device='mps:0')
# tensor([4.5133e-05, 1.0148e-04, 1.8451e-05], device='mps:0')
# tensor([3.7436e-06, 2.0641e-05, 3.7581e-06], device='mps:0')
# tensor([1.0957e-05, 4.6095e-05, 7.5759e-06], device='mps:0')
# tensor([2.7498e-06, 1.5865e-05, 3.1203e-06], device='mps:0')
# tensor([1.3060e-05, 5.1322e-05, 8.4851e-06], device='mps:0')
# tensor([5.6102e-05, 1.1295e-04, 2.1012e-05], device='mps:0')
# tensor([3.8526e-06, 2.1187e-05, 3.8301e-06], device='mps:0')
# tensor([1.0655e-05, 4.5000e-05, 7.3724e-06], device='mps:0')
# tensor([1.9172e-05, 6.4421e-05, 1.0897e-05], device='mps:0')
# tensor([8.3339e-06, 3.8732e-05, 6.3865e-06], device='mps:0')
# tensor([3.2236e-06, 1.8186e-05, 3.3866e-06], device='mps:0')
# tensor([8.8981e-05, 1.3644e-04, 2.8896e-05], device='mps:0')
# tensor([1.0372e-04, 1.4381e-04, 3.1738e-05], device='mps:0')
# tensor([4.7390e-06, 2.5140e-05, 4.3651e-06], device='mps:0')
# tensor([1.0198e-05, 4.3688e-05, 7.1614e-06], device='mps:0')
# tensor([1.5629e-05, 5.7861e-05, 9.6562e-06], device='mps:0')
# tensor([1.9310e-05, 6.4585e-05, 1.0990e-05], device='mps:0')
# tensor([3.3572e-05, 8.7644e-05, 1.5352e-05], device='mps:0')
# tensor([9.4501e-06, 4.2269e-05, 6.9533e-06], device='mps:0')
# tensor([9.4022e-06, 4.2318e-05, 6.9963e-06], device='mps:0')
# tensor([1.6980e-05, 5.9966e-05, 1.0045e-05], device='mps:0')
# tensor([3.8423e-06, 2.1133e-05, 3.8351e-06], device='mps:0')
# tensor([9.5734e-06, 4.2011e-05, 6.8678e-06], device='mps:0')
# tensor([9.4959e-06, 4.1576e-05, 6.8203e-06], device='mps:0')
# tensor([4.2665e-06, 2.2952e-05, 4.0580e-06], device='mps:0')
# tensor([1.1085e-05, 4.6829e-05, 7.7060e-06], device='mps:0')
# tensor([9.4121e-06, 4.2382e-05, 6.9637e-06], device='mps:0')
# tensor([5.2884e-05, 1.1210e-04, 2.0435e-05], device='mps:0')
# tensor([1.0979e-05, 4.6873e-05, 7.7745e-06], device='mps:0')
# tensor([5.7165e-06, 2.9181e-05, 4.9838e-06], device='mps:0')
# tensor([1.8325e-05, 6.3130e-05, 1.0580e-05], device='mps:0')
# tensor([3.3211e-05, 8.6898e-05, 1.5183e-05], device='mps:0')
# tensor([7.1059e-05, 1.2269e-04, 2.4419e-05], device='mps:0')
# tensor([9.8985e-05, 1.4090e-04, 3.0614e-05], device='mps:0')
# tensor([3.9164e-06, 2.1560e-05, 3.9055e-06], device='mps:0')
# tensor([5.0845e-05, 1.0872e-04, 1.9630e-05], device='mps:0')
# tensor([7.9796e-05, 1.2983e-04, 2.6246e-05], device='mps:0')
# tensor([1.1616e-05, 4.7417e-05, 7.8243e-06], device='mps:0')
# tensor([3.3309e-06, 1.8722e-05, 3.5150e-06], device='mps:0')
# tensor([5.2943e-05, 1.1005e-04, 2.0389e-05], device='mps:0')
# tensor([2.5879e-05, 7.6443e-05, 1.3009e-05], device='mps:0')
# tensor([4.5199e-05, 1.0219e-04, 1.7974e-05], device='mps:0')
# tensor([6.5596e-06, 3.1974e-05, 5.3629e-06], device='mps:0')
# tensor([7.5447e-06, 3.6105e-05, 6.0365e-06], device='mps:0')
# tensor([3.3654e-05, 8.7349e-05, 1.5369e-05], device='mps:0')
# tensor([8.1991e-06, 3.7112e-05, 5.9906e-06], device='mps:0')
# tensor([4.0668e-06, 2.2105e-05, 3.9627e-06], device='mps:0')
# tensor([2.7032e-05, 7.8860e-05, 1.3512e-05], device='mps:0')
# tensor([1.4598e-05, 5.5787e-05, 9.2988e-06], device='mps:0')
# tensor([1.1659e-04, 1.4731e-04, 3.4301e-05], device='mps:0')
# tensor([1.0402e-05, 4.4672e-05, 7.3873e-06], device='mps:0')
# tensor([4.0749e-06, 2.2463e-05, 4.0612e-06], device='mps:0')
# tensor([7.5525e-06, 3.6088e-05, 5.9857e-06], device='mps:0')
# tensor([4.8724e-06, 2.5660e-05, 4.4427e-06], device='mps:0')
# tensor([8.0660e-06, 3.7923e-05, 6.2667e-06], device='mps:0')
# tensor([1.0049e-05, 4.4034e-05, 7.1941e-06], device='mps:0')
# tensor([3.6775e-06, 2.0429e-05, 3.7524e-06], device='mps:0')
# tensor([9.9052e-06, 4.3022e-05, 7.1132e-06], device='mps:0')
# tensor([3.7436e-06, 2.0641e-05, 3.7581e-06], device='mps:0')
# tensor([2.2266e-05, 7.0494e-05, 1.2115e-05], device='mps:0')
# tensor([9.5833e-06, 4.2655e-05, 7.0087e-06], device='mps:0')
# tensor([8.2768e-06, 3.7795e-05, 6.2566e-06], device='mps:0')
# tensor([2.4556e-05, 7.3694e-05, 1.2430e-05], device='mps:0')
# tensor([5.7080e-05, 1.1422e-04, 2.1117e-05], device='mps:0')
# tensor([9.7103e-06, 4.3084e-05, 7.0940e-06], device='mps:0')
# tensor([1.4553e-05, 5.5575e-05, 9.2174e-06], device='mps:0')
# tensor([5.2896e-05, 1.1003e-04, 2.0319e-05], device='mps:0')
# tensor([8.9980e-06, 4.0913e-05, 6.7392e-06], device='mps:0')
# tensor([8.8232e-06, 4.0225e-05, 6.6028e-06], device='mps:0')
# tensor([1.5947e-05, 5.8016e-05, 9.4127e-06], device='mps:0')
# tensor([6.5971e-06, 3.2548e-05, 5.4610e-06], device='mps:0')
# tensor([1.0467e-05, 4.5346e-05, 7.4817e-06], device='mps:0')
# tensor([9.4022e-06, 4.2318e-05, 6.9963e-06], device='mps:0')
# tensor([6.5908e-06, 3.2045e-05, 5.3766e-06], device='mps:0')
# tensor([1.4962e-05, 5.6674e-05, 9.3980e-06], device='mps:0')
# tensor([7.8669e-06, 3.7185e-05, 6.1765e-06], device='mps:0')
# tensor([6.0062e-05, 1.1231e-04, 2.1084e-05], device='mps:0')
# tensor([1.5299e-05, 5.6483e-05, 9.4532e-06], device='mps:0')
# tensor([4.5129e-06, 2.4230e-05, 4.2412e-06], device='mps:0')
# tensor([1.1723e-05, 4.7954e-05, 7.8817e-06], device='mps:0')
# tensor([9.2670e-06, 4.1929e-05, 6.9163e-06], device='mps:0')
# tensor([3.7436e-06, 2.0641e-05, 3.7581e-06], device='mps:0')
# tensor([4.4814e-05, 1.0174e-04, 1.8204e-05], device='mps:0')
# tensor([4.8126e-05, 1.0574e-04, 1.9006e-05], device='mps:0')
# tensor([1.8586e-05, 6.3332e-05, 1.0393e-05], device='mps:0')
# tensor([2.7498e-06, 1.5865e-05, 3.1203e-06], device='mps:0')
# tensor([1.6164e-05, 5.8754e-05, 9.7461e-06], device='mps:0')
# tensor([5.5135e-06, 2.8050e-05, 4.8402e-06], device='mps:0')
# tensor([2.0459e-05, 6.7107e-05, 1.1420e-05], device='mps:0')
# tensor([7.6150e-06, 3.5529e-05, 5.9177e-06], device='mps:0')
# tensor([3.9164e-06, 2.1560e-05, 3.9055e-06], device='mps:0')
# tensor([3.8820e-06, 2.1300e-05, 3.8563e-06], device='mps:0')
# tensor([1.2959e-05, 5.0688e-05, 8.4384e-06], device='mps:0')
# tensor([1.9824e-05, 6.5662e-05, 1.1243e-05], device='mps:0')
# tensor([1.3094e-05, 5.1955e-05, 8.5448e-06], device='mps:0')
# tensor([6.1075e-05, 1.1274e-04, 2.1313e-05], device='mps:0')
# tensor([1.2572e-05, 5.0046e-05, 8.2792e-06], device='mps:0')
# tensor([6.1303e-06, 3.0706e-05, 5.1327e-06], device='mps:0')
# tensor([5.7145e-05, 1.1526e-04, 2.1439e-05], device='mps:0')
# tensor([2.0666e-05, 6.8078e-05, 1.1510e-05], device='mps:0')
# tensor([6.5920e-06, 3.2592e-05, 5.3973e-06], device='mps:0')
# tensor([2.4007e-05, 7.2855e-05, 1.2577e-05], device='mps:0')
# tensor([1.3722e-05, 5.2798e-05, 8.8254e-06], device='mps:0')
# tensor([2.2676e-05, 7.1653e-05, 1.2169e-05], device='mps:0')
# tensor([5.8916e-06, 2.9397e-05, 5.0058e-06], device='mps:0')
# tensor([1.9145e-05, 6.4418e-05, 1.0583e-05], device='mps:0')
# tensor([6.7971e-06, 3.3296e-05, 5.5391e-06], device='mps:0')
# tensor([2.2580e-05, 7.1125e-05, 1.1824e-05], device='mps:0')
# tensor([7.4983e-06, 3.5967e-05, 6.0045e-06], device='mps:0')
# tensor([1.2513e-05, 5.0663e-05, 8.3577e-06], device='mps:0')
# tensor([1.0933e-05, 4.6570e-05, 7.6791e-06], device='mps:0')
# tensor([8.5385e-06, 3.9440e-05, 6.4663e-06], device='mps:0')
# tensor([3.1238e-05, 8.4067e-05, 1.4590e-05], device='mps:0')
# tensor([1.2363e-04, 1.4958e-04, 3.5797e-05], device='mps:0')
# tensor([1.1673e-05, 4.7707e-05, 7.8196e-06], device='mps:0')
# tensor([1.2265e-05, 4.9865e-05, 8.1921e-06], device='mps:0')
# tensor([1.5050e-05, 5.6237e-05, 9.0834e-06], device='mps:0')
# tensor([3.7873e-06, 2.1015e-05, 3.8245e-06], device='mps:0')
# tensor([5.2744e-05, 1.0348e-04, 1.8645e-05], device='mps:0')
# tensor([4.1950e-05, 9.9122e-05, 1.7641e-05], device='mps:0')
# tensor([6.8748e-06, 3.3729e-05, 5.5981e-06], device='mps:0')
# tensor([3.6069e-05, 9.1298e-05, 1.5981e-05], device='mps:0')
# tensor([2.7137e-06, 1.5774e-05, 3.1495e-06], device='mps:0')
# tensor([7.2082e-06, 3.4678e-05, 5.7600e-06], device='mps:0')
# tensor([6.9233e-06, 3.3145e-05, 5.5590e-06], device='mps:0')
# tensor([1.0850e-04, 1.4570e-04, 3.2701e-05], device='mps:0')
# tensor([3.5450e-06, 1.9705e-05, 3.5997e-06], device='mps:0')
# tensor([1.4510e-05, 5.4606e-05, 9.1161e-06], device='mps:0')
# tensor([1.7456e-05, 6.1532e-05, 1.0284e-05], device='mps:0')
# tensor([2.2622e-05, 7.1000e-05, 1.1881e-05], device='mps:0')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 10
#       8 train_users = [user_list[i] for i in train_idx]
#       9 val_users = [user_list[i] for i in val_idx]
# ---> 10 model,val_hr =  train_model(train_users, val_users, fold_num)
#      11 fold_results[fold_num] = val_hr
#      12 save_path = f"results/results_item_with_bert/fold_{fold_num}"
#
# Cell In[20], line 55, in train_model(train_users, val_users, fold_num)
#      53 # val_user_item_sequences = {user: seq for user, seq in user_item_sequence.items() if user in val_users}
#      54 val_item_sequences = {user: seq for user, seq in user_item_to_index_sequence.items() if user in val_users}
# ---> 55 val_hr = evaluate_model(model, val_item_sequences,k=5)
#      56 print(f"Fold {fold_num} Epoch {epoch+1}, Validation HR@5: {val_hr}")
#      57 if val_hr > best_hr:
#
# Cell In[19], line 44, in evaluate_model(model, val_item_sequences, k)
#      40 item_tensor = torch.tensor([padded_items], dtype=torch.long).to(device)
#      42 key_padding_mask = (item_tensor == 0)
# ---> 44 logits = model(item_tensor, key_padding_mask=key_padding_mask)[:,min(len(item_seq)-1,max_len-1),:]
#      45 probabilities = torch.softmax(logits, dim=-1)
#      46 print(probabilities[0,[2,5,7]])
#
# File ~/.pyenv/versions/3.10.12/envs/thesis-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.12/envs/thesis-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# Cell In[14], line 24, in BertModel.forward(self, input_ids, attention_mask, key_padding_mask)
#      23 def forward(self, input_ids, attention_mask=None,key_padding_mask=None):
# ---> 24     embedding_output = self.embeddings(input_ids)
#      25     encoder_output = self.encoder(embedding_output, attention_mask,key_padding_mask)
#      26     output = self.output_layer(encoder_output)
#
# File ~/.pyenv/versions/3.10.12/envs/thesis-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.12/envs/thesis-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# Cell In[11], line 13, in BertEmbeddings.forward(self, input_ids)
#      11 position_ids = torch.arange(self.max_len, dtype=torch.long, device=input_ids.device).unsqueeze(0)
#      12 word_emb = self.word_embeddings(input_ids)
# ---> 13 pos_emb = self.position_encoding(position_ids)
#      14 embeddings = word_emb + pos_emb
#      15 embeddings = self.LayerNorm(embeddings)
#
# File ~/.pyenv/versions/3.10.12/envs/thesis-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.12/envs/thesis-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/3.10.12/envs/thesis-env/lib/python3.10/site-packages/torch/nn/modules/sparse.py:190, in Embedding.forward(self, input)
#     189 def forward(self, input: Tensor) -> Tensor:
# --> 190     return F.embedding(
#     191         input,
#     192         self.weight,
#     193         self.padding_idx,
#     194         self.max_norm,
#     195         self.norm_type,
#     196         self.scale_grad_by_freq,
#     197         self.sparse,
#     198     )
#
# File ~/.pyenv/versions/3.10.12/envs/thesis-env/lib/python3.10/site-packages/torch/nn/functional.py:2551, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2545     # Note [embedding_renorm set_grad_enabled]
#    2546     # XXX: equivalent to
#    2547     # with torch.no_grad():
#    2548     #   torch.embedding_renorm_
#    2549     # remove once script supports set_grad_enabled
#    2550     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2551 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# KeyboardInterrupt:
